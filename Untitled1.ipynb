# %%
import pandas as p
import matplotlib.pyplot as plt

# %%
# Load the file uploaded by the user
file_path = 'Resources/Sleep_health_and_lifestyle_dataset.csv'
data = pd.read_csv(file_path)

# %%
# Display the first few rows of the data to understand its structure
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
# Data Cleaning
# Convert columns to numeric types using astype
data['Physical Activity Level'] = data['Physical Activity Level'].astype(float)
data['Stress Level'] = data['Stress Level'].astype(float)
data['Daily Steps'] = data['Daily Steps'].astype(int)
data['Quality of Sleep'] = data['Quality of Sleep'].astype(float)

data.dropna(inplace=True)

# %%
data.dropna(inplace=True)
data_cleaned.head()
# Out:
#    Age  Gender family_history treatment work_interfere remote_work  \
# 0   37  Female             No       Yes          Often          No
# 1   44       M             No        No         Rarely          No
# 2   32    Male             No        No         Rarely          No
# 3   31    Male            Yes       Yes          Often          No
# 4   31    Male             No        No          Never         Yes
#
#   tech_company    benefits care_options wellness_program  ...   anonymity  \
# 0          Yes         Yes     Not sure               No  ...         Yes
# 1           No  Don't know           No       Don't know  ...  Don't know
# 2          Yes          No           No               No  ...  Don't know
# 3          Yes          No          Yes               No  ...          No
# 4          Yes         Yes           No       Don't know  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
filtered_data = data[(data['Occupation'] != 'Doctor') & 
                     (data['Occupation'] != 'Teacher') & 
                     (data['Occupation'] != 'Nurse')]
print(filtered_data.head())
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 80         81  Female   34             Scientist             5.8
# 81         82  Female   34             Scientist             5.8
#
#     Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                4.0                     30.0           8.0        Obese
# 4                4.0                     30.0           8.0        Obese
# 5                4.0                     30.0           8.0        Obese
# 80               4.0                     32.0           8.0   Overweight
# 81               4.0                     32.0           8.0   Overweight
#
#    Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3          140/90          85         3000    Sleep Apnea
# ...

# %%
plt.figure(figsize=(10, 6))
filtered_data.groupby('Physical Activity Level')['Stress Level'].mean().plot(kind='bar', color='blue')
plt.title('Average Stress Level by Physical Activity Level')
plt.xlabel('Physical Activity Level')
plt.ylabel('Average Stress Level')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
filtered_data.groupby('Daily Steps')['Quality of Sleep'].mean().plot(kind='bar', color='green')
plt.title('Average Sleep Quality by Daily Steps')
plt.xlabel('Daily Steps')
plt.ylabel('Average Quality of Sleep')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()
